# %% [markdown]
# fastapi_app/
# ├── app/
# │   ├── __init__.py
# │   ├── main.py                # App entry point, ties everything together
# │   ├── core/                  # Global config, security, base settings
# │   │   ├── __init__.py
# │   │   ├── config.py
# │   │   └── security.py
# │   ├── api/                   # API routes (v1, v2, etc.)
# │   │   ├── __init__.py
# │   │   └── v1/
# │   │       ├── __init__.py
# │   │       ├── users.py
# │   │       └── items.py
# │   ├── models/                # ORM models (SQLAlchemy)
# │   │   ├── __init__.py
# │   │   ├── user.py
# │   │   └── item.py
# │   ├── schemas/               # Pydantic schemas (data validation)
# │   │   ├── __init__.py
# │   │   ├── user.py
# │   │   └── item.py
# │   ├── services/              # Business logic (used by routers)
# │   │   ├── __init__.py
# │   │   └── user_service.py
# │   ├── db/                    # Database session management
# │   │   ├── __init__.py
# │   │   ├── base.py
# │   │   └── session.py
# │   └── tests/                 # Unit and integration tests
# │       ├── __init__.py
# │       ├── test_users.py
# │       └── test_items.py
# ├── .env                       # Environment variables
# ├── alembic/                   # Database migrations
# ├── requirements.txt           # Project dependencies
# └── README.md
